# %% [markdown]
# <a href="https://colab.research.google.com/github/sway-am/Rep_CCGC/blob/main/CCGC_MLRC/Notebooks/Grid_Search_Additional_Graph_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CCGC_MLRC
# Out:
# /content/drive/MyDrive/CCGC_MLRC

# %%
# !pip install munkres

# %%
# !pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/CCGC_MLRC
# Out:
# /content/drive/MyDrive/CCGC_MLRC

# %%
# !unzip dblp.zip
# Out:
# Archive:  dblp.zip
#   inflating: dblp_adj.npy
# replace dblp_feat.npy? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: dblp_feat.npy
# replace dblp_label.npy? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: dblp_label.npy

# %%
alpha = [0.1,0.5,1,10]
tau = [0.5,0.65,0.7]

dimens = 334
classes = 4
dataset = "dblp"


for x in alpha:
  for y in tau:
     # !python train.py --alpha $x --threshold $y --dims $dimens --cluster_num $classes --dataset $dataset
# Out:
# Alpha: 0.1
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    dblp
# feature shape:   (4057, 334)
# label shape:     (4057,)
# adj shape:       (4057, 4057)
# undirected edge num:    3528
# category num:           4
# category distribution:
# label 0:1197
# label 1:745
# label 2:1109
# label 3:1006
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:15<00:00, 26.19it/s]
# 100% 400/400 [00:14<00:00, 27.26it/s]
# 100% 400/400 [00:14<00:00, 27.60it/s]
# 100% 400/400 [00:14<00:00, 26.76it/s]
# 100% 400/400 [00:14<00:00, 27.00it/s]
# 100% 400/400 [00:14<00:00, 26.96it/s]
# 100% 400/400 [00:14<00:00, 27.31it/s]
# 100% 400/400 [00:14<00:00, 27.09it/s]
# 100% 400/400 [00:14<00:00, 27.86it/s]
# 100% 400/400 [00:14<00:00, 27.39it/s]
# 54.16563963519842 ± 2.914984971587221
# 25.74465911129301 ± 2.7398234430347808
# 20.567218445832314 ± 4.658266789909863
# 53.26565384975153 ± 2.235521874839598
# Alpha: 0.1
# ...

# %%
# %cd /content/drive/MyDrive/CCGC_MLRC
# Out:
# /content/drive/MyDrive/CCGC_MLRC

# %%
# !unzip amac.zip
# Out:
# Archive:  amac.zip
#    creating: amac/
#   inflating: amac/amac_adj.npy
#   inflating: amac/amac_feat.npy
#   inflating: amac/amac_label.npy

# %%
alpha = [0.1,0.5,1,10]
tau = [0.5,0.65,0.7]

dimens = 767
classes = 10
dataset = "amac"


for x in alpha:
  for y in tau:
     # !python train.py --alpha $x --threshold $y --dims $dimens --cluster_num $classes --dataset $dataset
# Out:
# Alpha: 0.1
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    amac
# feature shape:   (13752, 767)
# label shape:     (13752,)
# adj shape:       (13752, 13752)
# undirected edge num:    80062
# category num:           10
# category distribution:
# label 0:436
# label 1:2142
# label 2:1414
# label 3:542
# label 4:5158
# label 5:308
# label 6:487
# label 7:818
# label 8:2156
# label 9:291
# ++++++++++++++++++++++++++++++
# 100% 400/400 [01:11<00:00,  5.61it/s]
# 100% 400/400 [01:13<00:00,  5.48it/s]
# 100% 400/400 [01:13<00:00,  5.44it/s]
# 100% 400/400 [01:13<00:00,  5.42it/s]
# 100% 400/400 [01:13<00:00,  5.42it/s]
# 100% 400/400 [01:14<00:00,  5.34it/s]
# 100% 400/400 [01:13<00:00,  5.47it/s]
# 100% 400/400 [01:13<00:00,  5.46it/s]
# 100% 400/400 [01:13<00:00,  5.45it/s]
# 100% 400/400 [01:13<00:00,  5.41it/s]
# 55.44284467713787 ± 1.3160888274325617
# 35.21741049867147 ± 1.2169609304739126
# ...

# %%
alpha = [1,10]
tau = [0.5,0.65,0.7]

dimens = 767
classes = 10
dataset = "amac"


for x in alpha:
  for y in tau:
     # !python train.py --alpha $x --threshold $y --dims $dimens --cluster_num $classes --dataset $dataset
# Out:
# Alpha: 1.0
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    amac
# feature shape:   (13752, 767)
# label shape:     (13752,)
# adj shape:       (13752, 13752)
# undirected edge num:    80062
# category num:           10
# category distribution:
# label 0:436
# label 1:2142
# label 2:1414
# label 3:542
# label 4:5158
# label 5:308
# label 6:487
# label 7:818
# label 8:2156
# label 9:291
# ++++++++++++++++++++++++++++++
# 100% 400/400 [01:11<00:00,  5.61it/s]
# 100% 400/400 [01:11<00:00,  5.59it/s]
# 100% 400/400 [01:11<00:00,  5.60it/s]
# 100% 400/400 [01:12<00:00,  5.54it/s]
# 100% 400/400 [01:12<00:00,  5.50it/s]
# 100% 400/400 [01:13<00:00,  5.46it/s]
# 100% 400/400 [01:12<00:00,  5.54it/s]
# 100% 400/400 [01:12<00:00,  5.52it/s]
# 100% 400/400 [01:12<00:00,  5.54it/s]
# 100% 400/400 [01:12<00:00,  5.51it/s]
# 55.44284467713787 ± 1.3160888274325617
# 35.217410498671455 ± 1.2169609304739284
# ...

# %%
# %cd /content/drive/MyDrive/CCGC_MLRC
# Out:
# /content/drive/MyDrive/CCGC_MLRC

# %%
alpha = [0.1,0.5,1,10]
tau = [0.5,0.65,0.7]

dimens = 1703
classes = 5
dataset = "texas"


for x in alpha:
  for y in tau:
     # !python train.py --alpha $x --threshold $y --dims $dimens --cluster_num $classes --dataset $dataset
# Out:
# Alpha: 0.1
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    texas
# feature shape:   (183, 1703)
# label shape:     (183,)
# adj shape:       (183, 183)
# undirected edge num:    162
# category num:           5
# category distribution:
# label 0:33
# label 1:1
# label 2:18
# label 3:101
# label 4:30
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:05<00:00, 79.02it/s]
# 100% 400/400 [00:03<00:00, 101.40it/s]
# 100% 400/400 [00:04<00:00, 83.96it/s]
# 100% 400/400 [00:04<00:00, 97.75it/s]
# 100% 400/400 [00:04<00:00, 92.08it/s]
# 100% 400/400 [00:04<00:00, 81.85it/s]
# 100% 400/400 [00:04<00:00, 94.48it/s]
# 100% 400/400 [00:04<00:00, 99.04it/s]
# 100% 400/400 [00:04<00:00, 87.35it/s]
# 100% 400/400 [00:04<00:00, 98.92it/s]
# 48.08743169398907 ± 1.9242422799627348
# 14.087251964285048 ± 0.8417763153480843
# 11.763927155206392 ± 2.544946214966678
# 30.330787377312674 ± 4.161113988461964
# ...

# %%
alpha = [0.1,0.5,1,10]
tau = [0.5,0.65,0.7]

dimens = 1703
classes = 5
dataset = "wisc"


for x in alpha:
  for y in tau:
     # !python train.py --alpha $x --threshold $y --dims $dimens --cluster_num $classes --dataset $dataset
# Out:
# Alpha: 0.1
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    wisc
# feature shape:   (251, 1703)
# label shape:     (251,)
# adj shape:       (251, 251)
# undirected edge num:    257
# category num:           5
# category distribution:
# label 0:10
# label 1:70
# label 2:118
# label 3:32
# label 4:21
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:10<00:00, 38.21it/s]
# 100% 400/400 [00:08<00:00, 48.80it/s]
# 100% 400/400 [00:04<00:00, 81.07it/s]
# 100% 400/400 [00:04<00:00, 90.86it/s]
# 100% 400/400 [00:04<00:00, 82.94it/s]
# 100% 400/400 [00:04<00:00, 81.86it/s]
# 100% 400/400 [00:04<00:00, 91.36it/s]
# 100% 400/400 [00:05<00:00, 73.44it/s]
# 100% 400/400 [00:04<00:00, 87.59it/s]
# 100% 400/400 [00:04<00:00, 88.92it/s]
# 44.58167330677291 ± 1.5060604120665961
# 8.17485546963411 ± 0.7442539280406247
# 3.230765351836213 ± 1.0243319257022365
# 26.708770296225055 ± 1.9960343068885136
# Alpha: 0.1
# ...

# %%
# %cd /content/drive/MyDrive/CCGC_MLRC/data

# %%
# !unzip acm.zip

# %%
alpha = [0.1,0.5,1,10]
tau = [0.5,0.65,0.7]

dimens = 1870
classes = 3
dataset = "acm"


for x in alpha:
  for y in tau:
     # !python train.py --alpha $x --threshold $y --dims $dimens --cluster_num $classes --dataset $dataset
# Out:
# Alpha: 0.1
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    acm
# feature shape:   (3025, 1870)
# label shape:     (3025,)
# adj shape:       (3025, 3025)
# undirected edge num:    13128
# category num:           3
# category distribution:
# label 0:1061
# label 1:965
# label 2:999
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:21<00:00, 18.83it/s]
# 100% 400/400 [00:21<00:00, 18.99it/s]
# 100% 400/400 [00:21<00:00, 18.62it/s]
# 100% 400/400 [00:21<00:00, 19.02it/s]
# 100% 400/400 [00:21<00:00, 18.83it/s]
# 100% 400/400 [00:20<00:00, 19.09it/s]
# 100% 400/400 [00:21<00:00, 18.86it/s]
# 100% 400/400 [00:21<00:00, 18.89it/s]
# 100% 400/400 [00:20<00:00, 19.16it/s]
# 100% 400/400 [00:21<00:00, 18.80it/s]
# 89.76528925619834 ± 0.3699526567547202
# 66.27334399357578 ± 0.9857928388188681
# 72.17547434568172 ± 0.9692863924616042
# 89.74754324574077 ± 0.35978425571574846
# Alpha: 0.1
# Threshold: 0.65
# ...
