# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
import os
from tqdm import tqdm
import warnings
import seaborn as sns
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CCGC_MLRC
# Out:
# /content/drive/MyDrive/CCGC_MLRC

# %%
# !pip install munkres
# !pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### cora

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'cora' --cluster_num $7 --dims $1433 --alpha $0.5
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    cora
# feature shape:   (2708, 1433)
# label shape:     (2708,)
# adj shape:       (2708, 2708)
# undirected edge num:    5278
# category num:           7
# category distribution:
# label 0:351
# label 1:217
# label 2:418
# label 3:818
# label 4:426
# label 5:298
# label 6:180
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:20<00:00, 19.95it/s]
# 100% 400/400 [00:19<00:00, 21.04it/s]
# 100% 400/400 [00:19<00:00, 20.23it/s]
# 100% 400/400 [00:19<00:00, 20.82it/s]
# 100% 400/400 [00:19<00:00, 20.40it/s]
# 100% 400/400 [00:19<00:00, 20.54it/s]
# 100% 400/400 [00:19<00:00, 20.27it/s]
# 100% 400/400 [00:20<00:00, 19.99it/s]
# 100% 400/400 [00:19<00:00, 20.46it/s]
# 100% 400/400 [00:19<00:00, 20.34it/s]
# 74.11004431314623 ± 0.9029464291204135
# 57.25138431693283 ± 0.7919151307738655
# 51.61337317903205 ± 1.8152065379056883
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # %run -i train.py --alpha $a --threshold $0.5 --cluster_num $7
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    cora
# feature shape:   (2708, 1433)
# label shape:     (2708,)
# adj shape:       (2708, 2708)
# undirected edge num:    5278
# category num:           7
# category distribution:
# label 0:351
# label 1:217
# label 2:418
# label 3:818
# label 4:426
# label 5:298
# label 6:180
# ++++++++++++++++++++++++++++++
# ...
# 100%|██████████| 400/400 [00:13<00:00, 30.53it/s]
# 73.7149187592319 ± 2.0461235057503617
# 56.74001458850874 ± 1.9938550007309925
# 51.35341053036757 ± 3.0568780040116135
# 69.3394891232232 ± 4.16468188193347
# Alpha: 0.1
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    cora
# feature shape:   (2708, 1433)
# label shape:     (2708,)
# adj shape:       (2708, 2708)
# undirected edge num:    5278
# category num:           7
# category distribution:
# ...

# %% [markdown]
# ### BAT

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'bat' --cluster_num $4 --alpha $0.5 --dims $81
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    bat
# feature shape:   (131, 81)
# label shape:     (131,)
# adj shape:       (131, 131)
# undirected edge num:    1038
# category num:           4
# category distribution:
# label 0:32
# label 1:32
# label 2:32
# label 3:35
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:03<00:00, 100.47it/s]
# 100% 400/400 [00:03<00:00, 116.66it/s]
# 100% 400/400 [00:03<00:00, 111.62it/s]
# 100% 400/400 [00:03<00:00, 128.27it/s]
# 100% 400/400 [00:03<00:00, 131.49it/s]
# 100% 400/400 [00:03<00:00, 114.18it/s]
# 100% 400/400 [00:03<00:00, 114.70it/s]
# 100% 400/400 [00:03<00:00, 124.81it/s]
# 100% 400/400 [00:03<00:00, 130.64it/s]
# 100% 400/400 [00:03<00:00, 109.53it/s]
# 70.76335877862596 ± 1.3676696845167056
# 48.765787556790464 ± 1.371824035264441
# 42.067743043988656 ± 2.0171942516713006
# 70.4684878662323 ± 1.4782672170081348
# Alpha: 0.5
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --threshold $0.5 --dataset $'bat' --cluster_num $4 --alpha $a --dims $81
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    bat
# feature shape:   (131, 81)
# label shape:     (131,)
# adj shape:       (131, 131)
# undirected edge num:    1038
# category num:           4
# category distribution:
# label 0:32
# label 1:32
# label 2:32
# label 3:35
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:03<00:00, 118.38it/s]
# 100% 400/400 [00:03<00:00, 130.24it/s]
# 100% 400/400 [00:03<00:00, 104.16it/s]
# 100% 400/400 [00:03<00:00, 127.38it/s]
# 100% 400/400 [00:03<00:00, 128.24it/s]
# 100% 400/400 [00:03<00:00, 130.05it/s]
# 100% 400/400 [00:03<00:00, 103.70it/s]
# 100% 400/400 [00:03<00:00, 129.69it/s]
# 100% 400/400 [00:03<00:00, 127.37it/s]
# 100% 400/400 [00:03<00:00, 127.94it/s]
# 70.53435114503817 ± 1.713736207682717
# 48.682540407266835 ± 1.1437783399483838
# 41.92228204931399 ± 1.7706098808560362
# 69.9413177607752 ± 2.7088549299265954
# Alpha: 0.1
# ...

# %% [markdown]
# ### UAT

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'uat' --cluster_num $4 --alpha $0.5 --dims $239
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    uat
# feature shape:   (1190, 239)
# label shape:     (1190,)
# adj shape:       (1190, 1190)
# undirected edge num:    13599
# category num:           4
# category distribution:
# label 0:297
# label 1:297
# label 2:297
# label 3:299
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:05<00:00, 68.85it/s]
# 100% 400/400 [00:06<00:00, 63.44it/s]
# 100% 400/400 [00:05<00:00, 72.42it/s]
# 100% 400/400 [00:06<00:00, 63.17it/s]
# 100% 400/400 [00:05<00:00, 72.47it/s]
# 100% 400/400 [00:06<00:00, 63.76it/s]
# 100% 400/400 [00:05<00:00, 72.96it/s]
# 100% 400/400 [00:06<00:00, 66.07it/s]
# 100% 400/400 [00:05<00:00, 69.61it/s]
# 100% 400/400 [00:05<00:00, 68.21it/s]
# 49.226890756302524 ± 1.5421026697410003
# 20.385238588225143 ± 1.8494116302777328
# 14.221696827767985 ± 1.606450724883563
# 47.156212575896895 ± 2.569228003905985
# Alpha: 0.5
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --threshold $0.5 --dataset $'uat' --cluster_num $4 --alpha $a --dims $239
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    uat
# feature shape:   (1190, 239)
# label shape:     (1190,)
# adj shape:       (1190, 1190)
# undirected edge num:    13599
# category num:           4
# category distribution:
# label 0:297
# label 1:297
# label 2:297
# label 3:299
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:06<00:00, 64.54it/s]
# 100% 400/400 [00:05<00:00, 69.18it/s]
# 100% 400/400 [00:06<00:00, 65.31it/s]
# 100% 400/400 [00:05<00:00, 72.09it/s]
# 100% 400/400 [00:06<00:00, 63.46it/s]
# 100% 400/400 [00:05<00:00, 70.66it/s]
# 100% 400/400 [00:06<00:00, 64.00it/s]
# 100% 400/400 [00:05<00:00, 71.26it/s]
# 100% 400/400 [00:06<00:00, 65.11it/s]
# 100% 400/400 [00:05<00:00, 72.80it/s]
# 50.336134453781504 ± 1.589102071068613
# 21.468244206796005 ± 1.7568529087561624
# 15.874473928252602 ± 1.8996181545480284
# 48.13788382122867 ± 3.063876265928879
# Alpha: 0.1
# ...

# %% [markdown]
# **CITEEER**

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'citeseer' --cluster_num $6 --alpha $0.5 --dims $3703
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    citeseer
# feature shape:   (3327, 3703)
# label shape:     (3327,)
# adj shape:       (3327, 3327)
# undirected edge num:    4614
# category num:           6
# category distribution:
# label 0:264
# label 1:590
# label 2:668
# label 3:701
# label 4:596
# label 5:508
# ++++++++++++++++++++++++++++++
# 100% 400/400 [01:06<00:00,  5.97it/s]
# 100% 400/400 [01:06<00:00,  6.05it/s]
# 100% 400/400 [01:06<00:00,  6.02it/s]
# 100% 400/400 [01:06<00:00,  5.98it/s]
# 100% 400/400 [01:05<00:00,  6.07it/s]
# 100% 400/400 [01:05<00:00,  6.07it/s]
# 100% 400/400 [01:06<00:00,  6.05it/s]
# 100% 400/400 [01:05<00:00,  6.07it/s]
# 100% 400/400 [01:05<00:00,  6.06it/s]
# 100% 400/400 [01:06<00:00,  6.03it/s]
# 69.4229035166817 ± 0.784260175519527
# 43.84728967092862 ± 0.9129310306754997
# 43.6929664002696 ± 0.9556055001214274
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --threshold $0.5 --dataset $'citeseer' --cluster_num $6 --alpha $a --dims $3703
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    citeseer
# feature shape:   (3327, 3703)
# label shape:     (3327,)
# adj shape:       (3327, 3327)
# undirected edge num:    4614
# category num:           6
# category distribution:
# label 0:264
# label 1:590
# label 2:668
# label 3:701
# label 4:596
# label 5:508
# ++++++++++++++++++++++++++++++
# 100% 400/400 [01:06<00:00,  6.03it/s]
# 100% 400/400 [01:05<00:00,  6.07it/s]
# 100% 400/400 [01:06<00:00,  6.05it/s]
# 100% 400/400 [01:06<00:00,  6.00it/s]
# 100% 400/400 [01:06<00:00,  6.05it/s]
# 100% 400/400 [01:06<00:00,  6.01it/s]
# 100% 400/400 [01:06<00:00,  6.06it/s]
# 100% 400/400 [01:06<00:00,  6.05it/s]
# 100% 400/400 [01:06<00:00,  6.02it/s]
# 100% 400/400 [01:06<00:00,  6.02it/s]
# 69.29666366095583 ± 0.8519745595459305
# 43.87257655478242 ± 0.8713995875318161
# 43.66883173095188 ± 0.9505878359443152
# ...

# %%
# !python train.py --threshold $0.5 --dataset $'citeseer' --cluster_num $6 --alpha $10 --dims $3703
# Out:
# Alpha: 10.0
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    citeseer
# feature shape:   (3327, 3703)
# label shape:     (3327,)
# adj shape:       (3327, 3327)
# undirected edge num:    4614
# category num:           6
# category distribution:
# label 0:264
# label 1:590
# label 2:668
# label 3:701
# label 4:596
# label 5:508
# ++++++++++++++++++++++++++++++
# 100% 400/400 [01:04<00:00,  6.16it/s]
# 100% 400/400 [01:06<00:00,  6.03it/s]
# 100% 400/400 [01:06<00:00,  6.01it/s]
# 100% 400/400 [01:06<00:00,  6.01it/s]
# 100% 400/400 [01:05<00:00,  6.11it/s]
#  72% 290/400 [00:50<00:19,  5.76it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/CCGC_MLRC/train.py", line 136, in <module>
#     acc, nmi, ari, f1, predict_labels, dis = clustering(hidden_emb, true_labels, args.cluster_num)
#   File "/content/drive/MyDrive/CCGC_MLRC/utils.py", line 506, in clustering
# ...

# %% [markdown]
# **EAT**

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'eat' --cluster_num $4 --alpha $0.5 --dims $203
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    eat
# feature shape:   (399, 203)
# label shape:     (399,)
# adj shape:       (399, 399)
# undirected edge num:    5994
# category num:           4
# category distribution:
# label 0:99
# label 1:99
# label 2:99
# label 3:102
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:04<00:00, 80.18it/s]
# 100% 400/400 [00:03<00:00, 107.04it/s]
# 100% 400/400 [00:03<00:00, 110.74it/s]
# 100% 400/400 [00:04<00:00, 99.02it/s]
# 100% 400/400 [00:03<00:00, 102.39it/s]
# 100% 400/400 [00:03<00:00, 109.05it/s]
# 100% 400/400 [00:03<00:00, 105.22it/s]
# 100% 400/400 [00:04<00:00, 95.04it/s]
# 100% 400/400 [00:03<00:00, 108.79it/s]
# 100% 400/400 [00:03<00:00, 109.93it/s]
# 56.8922305764411 ± 1.143033007618185
# 33.881639345223874 ± 0.9608105396841502
# 26.419417727950993 ± 1.1249068571453438
# 57.30980794303755 ± 1.2048339531213406
# Alpha: 0.5
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --threshold $0.5 --dataset $'eat' --cluster_num $4 --alpha $a --dims $203
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    eat
# feature shape:   (399, 203)
# label shape:     (399,)
# adj shape:       (399, 399)
# undirected edge num:    5994
# category num:           4
# category distribution:
# label 0:99
# label 1:99
# label 2:99
# label 3:102
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:04<00:00, 98.55it/s]
# 100% 400/400 [00:04<00:00, 89.87it/s]
# 100% 400/400 [00:03<00:00, 109.80it/s]
# 100% 400/400 [00:03<00:00, 107.10it/s]
# 100% 400/400 [00:04<00:00, 91.08it/s]
# 100% 400/400 [00:03<00:00, 108.57it/s]
# 100% 400/400 [00:03<00:00, 109.80it/s]
# 100% 400/400 [00:03<00:00, 103.04it/s]
# 100% 400/400 [00:03<00:00, 101.88it/s]
# 100% 400/400 [00:03<00:00, 112.39it/s]
# 56.39097744360902 ± 1.0924558755741036
# 33.44852879368781 ± 0.9749434381556924
# 26.207279539126574 ± 0.8456678582352676
# 56.752950347998805 ± 1.2153215360469
# Alpha: 0.1
# ...

# %% [markdown]
# **AMAP**

# %%
thresh = [ 0.5, 0.6, 0.7]
for t in thresh:
  # !python train.py --threshold $t --dataset $'amap' --cluster_num $8 --alpha $0.5 --dims $745
# Out:
# Alpha: 0.5
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    amap
# feature shape:   (7650, 745)
# label shape:     (7650,)
# adj shape:       (7650, 7650)
# undirected edge num:    119081
# category num:           8
# category distribution:
# label 0:369
# label 1:1686
# label 2:703
# label 3:915
# label 4:882
# label 5:823
# label 6:1941
# label 7:331
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:36<00:00, 10.94it/s]
# 100% 400/400 [00:35<00:00, 11.25it/s]
# 100% 400/400 [00:35<00:00, 11.37it/s]
# 100% 400/400 [00:35<00:00, 11.41it/s]
# 100% 400/400 [00:35<00:00, 11.34it/s]
# 100% 400/400 [00:35<00:00, 11.18it/s]
# 100% 400/400 [00:35<00:00, 11.33it/s]
# 100% 400/400 [00:35<00:00, 11.31it/s]
# 100% 400/400 [00:35<00:00, 11.33it/s]
# 100% 400/400 [00:35<00:00, 11.25it/s]
# 77.41437908496731 ± 0.398673523587927
# 67.39602976489775 ± 0.9683263137512435
# 58.31761245035083 ± 0.5208293428846216
# ...

# %%
alpha = [ 0.01,0.1,1,10]
for a in alpha:
  # !python train.py --threshold $0.5 --dataset $'amap' --cluster_num $8 --alpha $a --dims $745
# Out:
# Alpha: 0.01
# Threshold: 0.5
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    amap
# feature shape:   (7650, 745)
# label shape:     (7650,)
# adj shape:       (7650, 7650)
# undirected edge num:    119081
# category num:           8
# category distribution:
# label 0:369
# label 1:1686
# label 2:703
# label 3:915
# label 4:882
# label 5:823
# label 6:1941
# label 7:331
# ++++++++++++++++++++++++++++++
# 100% 400/400 [00:35<00:00, 11.31it/s]
# 100% 400/400 [00:34<00:00, 11.45it/s]
# 100% 400/400 [00:34<00:00, 11.44it/s]
# 100% 400/400 [00:34<00:00, 11.49it/s]
# 100% 400/400 [00:34<00:00, 11.43it/s]
# 100% 400/400 [00:35<00:00, 11.31it/s]
# 100% 400/400 [00:34<00:00, 11.50it/s]
# 100% 400/400 [00:34<00:00, 11.50it/s]
# 100% 400/400 [00:34<00:00, 11.50it/s]
# 100% 400/400 [00:35<00:00, 11.32it/s]
# 77.35555555555555 ± 0.6297357638720752
# 67.34304328937245 ± 1.0353778352849363
# 58.01203598683983 ± 0.6582070564215625
# ...

# %%
# !python train.py --threshold $0.7 --dataset $'bat' --cluster_num $4 --alpha $10 --dims $81 --epochs $410
# Out:
# Alpha: 10.0
# Threshold: 0.7
# ++++++++++++++++++++++++++++++
# ---details of graph dataset---
# ++++++++++++++++++++++++++++++
# dataset name:    bat
# feature shape:   (131, 81)
# label shape:     (131,)
# adj shape:       (131, 131)
# undirected edge num:    1038
# category num:           4
# category distribution:
# label 0:32
# label 1:32
# label 2:32
# label 3:35
# ++++++++++++++++++++++++++++++
# 100% 410/410 [00:01<00:00, 296.32it/s]
# 100% 410/410 [00:01<00:00, 340.48it/s]
# 100% 410/410 [00:01<00:00, 340.08it/s]
# 100% 410/410 [00:01<00:00, 339.77it/s]
# 100% 410/410 [00:01<00:00, 337.71it/s]
# 100% 410/410 [00:01<00:00, 265.17it/s]
# 100% 410/410 [00:01<00:00, 260.06it/s]
# 100% 410/410 [00:01<00:00, 345.19it/s]
# 100% 410/410 [00:01<00:00, 322.27it/s]
# 100% 410/410 [00:01<00:00, 337.48it/s]
# 69.69465648854963 ± 1.9326700612476595
# 47.25841611403946 ± 1.8149707310322818
# 40.892561284721076 ± 1.2701329704912834
# 68.74840201107958 ± 3.4436562420689025
